# %%
"""Six functions for each of the six letters
The code for each letter is designed so individual rows can be
picked out and added to a string with the corresponding row 
of other letters when a word is typed in. 
Needs to be used in conjuction with write_word function."""

"""Function for returning O"""
def write_O(current_line, row):
    for column in range(0, 5):
        if row in (0, 4):
            if column in (0, 4):
                current_line = current_line + " "
            else:
                current_line = current_line + "*"
        else:
            if column in (1, 2, 3):
                current_line = current_line + " "
            else:
                current_line = current_line + "*"
    return current_line

"""Function for returning X"""
def write_X(current_line, row):
    for column in range(0, 5):
        if row in (0, 4):
            if column in (0, 4):
                current_line = current_line + "*"
            else:
                current_line = current_line + " "
        elif row in (1, 3):
            if column in (1, 3):
                current_line = current_line + "*"
            else:
                current_line = current_line + " "
        else:
            if column == 2:
                current_line = current_line + "*"
            else:
                current_line = current_line + " "
    return current_line

"""Function for returning Y"""
def write_Y(current_line, row):
    for column in range(0, 5):
        if row == 0:
            if column in (0, 4):
                current_line = current_line + "*"
            else:
                current_line = current_line + " "
        elif row == 1:
            if column in (1, 3):
                current_line = current_line + "*"
            else:
                current_line = current_line + " "
        else:
            if column == 2:
                current_line = current_line + "*"
            else:
                current_line = current_line + " "
    return current_line


"""Function for returning G"""
def write_G(current_line, row):
    for column in range(0, 5):
        if row == 0:
            if column in (1, 2, 3, 4):
                current_line = current_line + "*"
            else:
                current_line = current_line + " "
        elif row == 1:
            if column == 0:
                current_line = current_line + "*"
            else:
                current_line = current_line + " "
        elif row == 2:
            if column in (0, 2, 3, 4):
                current_line = current_line + "*"
            else:
                current_line = current_line + " "
        elif row == 3:
            if column in (0, 4):
                current_line = current_line + "*"
            else:
                current_line = current_line + " "
        else:
            if column in (1, 2, 3):
                current_line = current_line + "*"
            else:
                current_line = current_line + " "
    return current_line


"""Function for returning E"""
def write_E(current_line, row):
    for column in range(0, 5):
        if row in (0, 2, 4):
            if column in (0, 1, 2, 3, 4):
                current_line = current_line + "*"
            else:
                current_line = current_line + " "
        elif row in (1, 3):
            if column == 0:
                current_line = current_line + "*"
            else:
                current_line = current_line + " "
    return current_line


"""Function for returning N"""
def write_N(current_line, row):
    for column in range(0, 5):
        if row in (0, 4):
            if column in (0, 4):
                current_line = current_line + "*"
            else:
                current_line = current_line + " "
        elif row == 1:
            if column in (0, 1, 4):
                current_line = current_line + "*"
            else:
                current_line = current_line + " "
        elif row == 2:
            if column in (0, 2, 4):
                current_line = current_line + "*"
            else:
                current_line = current_line + " "
        elif row == 3:
            if column in (0, 3, 4):
                current_line = current_line + "*"
            else:
                current_line = current_line + " "
    return current_line

# %%
"""This is the code for the function that prints a combination of valid letters input by the user.
Code is designed so when the user enters a valid word/letter combination, the corresponding row/line from each letter 
is taken and printed next to each other."""


def write_word(valid_input):
    for i in range(0, 5):
        row_result = ""
        for j in valid_input:
            if j == "o":
                row_result = write_O(row_result, i)
            if j == "x":
                row_result = write_X(row_result, i)
            if j == "y":
                row_result = write_Y(row_result, i)
            if j == "g":
                row_result = write_G(row_result, i)
            if j == "e":
                row_result = write_E(row_result, i)
            if j == "n":
                row_result = write_N(row_result, i)
        print(row_result)

# %%
"""MAIN CODE
Main code includes functions for each individual letter, a function (write_word) to print word/letter input by the user, 
a function (is_valid_input) for validating user input and code to break the loop if user types in the END command."""

"""Function that defines and returns the letter O"""           
def write_O(current_line, row):
    for column in range(0, 5):
        if row in (0, 4):
            if column in (0, 4):
                current_line = current_line + " "
            else:
                current_line = current_line + "*"
        else:
            if column in (1, 2, 3):
                current_line = current_line + " "
            else:
                current_line = current_line + "*"
    return current_line

"Function that defines and returns the letter X"
def write_X(current_line, row):
    for column in range(0, 5):
        if row in (0, 4):
            if column in (0, 4):
                current_line = current_line + "*"
            else:
                current_line = current_line + " "
        elif row in (1, 3):
            if column in (1, 3):
                current_line = current_line + "*"
            else:
                current_line = current_line + " "
        else:
            if column == 2:
                current_line = current_line + "*"
            else:
                current_line = current_line + " "
    return current_line


"""Function that defines and returns the letter Y"""
def write_Y(current_line, row):
    for column in range(0, 5):
        if row == 0:
            if column in (0, 4):
                current_line = current_line + "*"
            else:
                current_line = current_line + " "
        elif row == 1:
            if column in (1, 3):
                current_line = current_line + "*"
            else:
                current_line = current_line + " "
        else:
            if column == 2:
                current_line = current_line + "*"
            else:
                current_line = current_line + " "
    return current_line


"""Function that defines and returns the letter G"""
def write_G(current_line, row):
    for column in range(0, 5):
        if row == 0:
            if column in (1, 2, 3, 4):
                current_line = current_line + "*"
            else:
                current_line = current_line + " "
        elif row == 1:
            if column == 0:
                current_line = current_line + "*"
            else:
                current_line = current_line + " "
        elif row == 2:
            if column in (0, 2, 3, 4):
                current_line = current_line + "*"
            else:
                current_line = current_line + " "
        elif row == 3:
            if column in (0, 4):
                current_line = current_line + "*"
            else:
                current_line = current_line + " "
        else:
            if column in (1, 2, 3):
                current_line = current_line + "*"
            else:
                current_line = current_line + " "
    return current_line


"""Function that defines and returns the letter E"""
def write_E(current_line, row):
    for column in range(0, 5):
        if row in (0, 2, 4):
            if column in (0, 1, 2, 3, 4):
                current_line = current_line + "*"
            else:
                current_line = current_line + " "
        elif row in (1, 3):
            if column == 0:
                current_line = current_line + "*"
            else:
                current_line = current_line + " "
    return current_line


"""Function that defines and returns the letter N"""
def write_N(current_line, row):
    for column in range(0, 5):
        if row in (0, 4):
            if column in (0, 4):
                current_line = current_line + "*"
            else:
                current_line = current_line + " "
        elif row == 1:
            if column in (0, 1, 4):
                current_line = current_line + "*"
            else:
                current_line = current_line + " "
        elif row == 2:
            if column in (0, 2, 4):
                current_line = current_line + "*"
            else:
                current_line = current_line + " "
        elif row == 3:
            if column in (0, 3, 4):
                current_line = current_line + "*"
            else:
                current_line = current_line + " "
    return current_line


"""This is the code for the function that prints a combination of valid letters input by the user.
Code is designed so when the user enters a valid word/letter combination, the corresponding row/line from each letter 
is taken and printed next to each other."""
def write_word(valid_input):
    for i in range(0, 5):
        row_result = ""
        for j in valid_input:
            if j == "o":
                row_result = write_O(row_result, i)
            if j == "x":
                row_result = write_X(row_result, i)
            if j == "y":
                row_result = write_Y(row_result, i)
            if j == "g":
                row_result = write_G(row_result, i)
            if j == "e":
                row_result = write_E(row_result, i)
            if j == "n":
                row_result = write_N(row_result, i)
        print(row_result)


"""Code for validating character input to the letters O, X, Y, G, E, N (case insensitive).
Code is also designed to break loop if the word END (case sensitive) is entered.
Program will keep prompting user for input until valid letter combination or break word is entered."""
def is_valid_input(input_str):
    valid_chars = set('oxygen')
    return all(char in valid_chars for char in input_str)

while True:
    input_1 = input('> ')
    lowered_input = input_1.lower()
    if input_1 == 'END':
        print('Exiting the program...')
        break
    elif is_valid_input(lowered_input):
        print('Entry is valid')
        write_word(lowered_input)
        break
    else:
        print("Entry is not valid, please try again")
# Out:
# > o
# Entry is valid
#  ***
# *   *
# *   *
# *   *
#  ***
